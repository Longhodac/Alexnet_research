# %%
import numpy as np

# %%
# numpy main datatype is ndarray
a1 = np.array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[1, 2.2, 3], [1,2,3.5]])
a3 = np.array([[[1, 2.2, 3], [1,2,3.5], [2,3,1]],[[1, 2.2, 3], [1,2,3.5], [2,3,1]] ])

# %%
a2
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.]])

# %%
a1.shape
# Out:
# (3,)

# %%
a3.ndim
# Out:
# 3

# %%
a3.shape
# Out:
# (2, 3, 3)

# %%
a3.dtype
# Out:
# dtype('float64')

# %%
a1.size, a2.size, a3.size
# Out:
# (3, 6, 18)

# %%
import pandas as pd

df = pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.2  3.0
# 1  1.0  2.0  3.5

# %%
sample_array = np.array([1, 2, 3])
sample_array
# Out:
# array([1, 2, 3])

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
ones = np.ones((2, 3))
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones.dtype
# Out:
# dtype('float64')

# %%
type(ones)
# Out:
# numpy.ndarray

# %%
zeros = np.zeros((2,3))
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0, 10, 2)
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0, 10, size=(3, 5))
random_array
# Out:
# array([[2, 0, 0, 3, 1],
#        [1, 3, 7, 0, 6],
#        [4, 1, 4, 6, 6]])

# %%
random_array.size
# Out:
# 15

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array2 = np.random.random((5, 3))
random_array2
# Out:
# array([[0.51243244, 0.49315607, 0.8666505 ],
#        [0.50830519, 0.1552881 , 0.67764945],
#        [0.77682826, 0.96232346, 0.07086038],
#        [0.31221255, 0.3742306 , 0.85450759],
#        [0.45567518, 0.7128616 , 0.71123951]])

# %%
random_array3 = np.random.rand(5, 3)
random_array3
# Out:
# array([[0.02008199, 0.77132062, 0.42202487],
#        [0.59841693, 0.25599978, 0.45662008],
#        [0.93002562, 0.43394335, 0.13738586],
#        [0.11268026, 0.79885603, 0.10468503],
#        [0.69704326, 0.16809168, 0.05031163]])

# %%
np.random.seed()
