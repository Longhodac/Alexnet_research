# %%
import numpy as np

# %%
# numpy main datatype is ndarray
a1 = np.array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[1, 2.2, 3], [1,2,3.5]])
a3 = np.array([[[1, 2.2, 3], [1,2,3.5], [2,3,1]],[[1, 2.2, 3], [1,2,3.5], [2,3,1]] ])

# %%
a2
# Out:
# array([[1. , 2.2, 3. ],
#        [1. , 2. , 3.5]])

# %%
a1.shape
# Out:
# (3,)

# %%
a3.ndim
# Out:
# 3

# %%
a3.shape
# Out:
# (2, 3, 3)

# %%
a3.dtype
# Out:
# dtype('float64')

# %%
a1.size, a2.size, a3.size
# Out:
# (3, 6, 18)

# %%
import pandas as pd

df = pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.2  3.0
# 1  1.0  2.0  3.5

# %%
sample_array = np.array([1, 2, 3])
sample_array
# Out:
# array([1, 2, 3])

# %%
sample_array.dtype
# Out:
# dtype('int32')

# %%
ones = np.ones((2, 3))
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones.dtype
# Out:
# dtype('float64')

# %%
type(ones)
# Out:
# numpy.ndarray

# %%
zeros = np.zeros((2,3))
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0, 10, 2)
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0, 10, size=(3, 5))
random_array
# Out:
# array([[8, 9, 7, 3, 5],
#        [4, 3, 7, 2, 2],
#        [7, 2, 1, 6, 5]])

# %%
random_array.size
# Out:
# 15

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array2 = np.random.random((5, 3))
random_array2
# Out:
# array([[0.76173307, 0.64225772, 0.95868767],
#        [0.24632687, 0.28982784, 0.27813608],
#        [0.43710905, 0.20314557, 0.6999395 ],
#        [0.94159559, 0.05925404, 0.91700667],
#        [0.63488067, 0.47553044, 0.79600866]])

# %%
random_array3 = np.random.rand(5, 3)
random_array3
# Out:
# array([[0.85885105, 0.2889266 , 0.49658916],
#        [0.52029633, 0.40162308, 0.06677662],
#        [0.34882713, 0.89795009, 0.95189849],
#        [0.89615671, 0.66880896, 0.02913125],
#        [0.67140518, 0.35301577, 0.03100737]])

# %%
np.random.seed(0)
random_array_4 = np.random.randint(10, size=(5,3))
random_array_4
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]])

# %%
np.random.seed(7)
random_array_5 = np.random.random((5, 3))
random_array_5
# Out:
# array([[0.07630829, 0.77991879, 0.43840923],
#        [0.72346518, 0.97798951, 0.53849587],
#        [0.50112046, 0.07205113, 0.26843898],
#        [0.4998825 , 0.67923   , 0.80373904],
#        [0.38094113, 0.06593635, 0.2881456 ]])

# %%
random_array_5 = np.random.random((5, 3))
random_array_5
# Out:
# array([[0.20484909, 0.49076589, 0.37238469],
#        [0.47740115, 0.36589039, 0.83791799],
#        [0.76864751, 0.31399468, 0.57262533],
#        [0.27604905, 0.45284293, 0.35297837],
#        [0.65739946, 0.37035108, 0.45909298]])
